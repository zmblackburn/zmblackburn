# %% [markdown]
# ## Exploratory Data Analysis for Boston House Price
# The Boston house price dataset can be accessed with the scikit-learn library. There are 506 samples and 13 feature variables in this dataset.
#
# Please follow the examples demonstrated in the class to carry out exploratory data analysis (EDA) for the Boston house price dataset.
#
# In your submssion:
#
# In addition to showing the output of the EDA, you will need to include the following:
#
# 1. a question about the Boston house price.
#
#   *any reasonable questions about the house price at Boston are ok. E.g., which ones are suitable for a family with school-age children? which units are suitable for a young couple who don't drive?)*
#
# 2. the answer to the question through the EDA and arguments to support it based on your findings.

# %%
from sklearn.datasets import load_boston
import pandas as pd
boston_data = load_boston()
print(boston_data["DESCR"])
df=pd.DataFrame(boston_data.data, columns=boston_data.feature_names)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df.describe().T #in this figure we can see datapoints and what ideal locations and results could be
# Out:
#          count        mean         std  ...        50%         75%       max
# CRIM     506.0    3.613524    8.601545  ...    0.25651    3.677083   88.9762
# ZN       506.0   11.363636   23.322453  ...    0.00000   12.500000  100.0000
# INDUS    506.0   11.136779    6.860353  ...    9.69000   18.100000   27.7400
# CHAS     506.0    0.069170    0.253994  ...    0.00000    0.000000    1.0000
# NOX      506.0    0.554695    0.115878  ...    0.53800    0.624000    0.8710
# RM       506.0    6.284634    0.702617  ...    6.20850    6.623500    8.7800
# AGE      506.0   68.574901   28.148861  ...   77.50000   94.075000  100.0000
# DIS      506.0    3.795043    2.105710  ...    3.20745    5.188425   12.1265
# RAD      506.0    9.549407    8.707259  ...    5.00000   24.000000   24.0000
# TAX      506.0  408.237154  168.537116  ...  330.00000  666.000000  711.0000
# PTRATIO  506.0   18.455534    2.164946  ...   19.05000   20.200000   22.0000
# ...

# %%
#for a young couple who does not drive I would look at DIS, the distance to major employers
#would also look at age and crime to keep safe 
#ideal situation would most likely be low crime and close to work
#most important is walkability though 
#from the data above we can make an inital finding on what we want to answer, ie family questions or young couple

# %%
df.hist(figsize=(10,10), bins=10);

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2) #this we can see the correlation between each column
# Out:
# <style  type="text/css" >
# #T_e557e1fc_345e_11eb_9b13_0242ac1c0002row0_col0,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row1_col1,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row2_col2,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row3_col3,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row4_col4,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row5_col5,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row6_col6,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row7_col7,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row8_col8,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row9_col9,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row10_col10,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row11_col11,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row12_col12{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row0_col1,#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row3_col0{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_e557e1fc_345e_11eb_9b13_0242ac1c0002row0_col2{
# ...

# %%
df.plot.scatter(x='DIS',y='AGE')

# %%
#above the closer the distance is the older the unit is the closer it will be to a place of work
